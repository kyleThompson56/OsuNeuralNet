# %%
import torch

print("Cuda available:", torch.cuda.is_available())
print("Device name:", torch.cuda.get_device_name
# Out:
# Cuda available: True

# %%
import mss

sct = mss.mss()
print("Detected monitors:", sct.monitors)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import mss
# ----> 3 sct = mss.mss()
#       4 print("Detected monitors:", sct.monitors)
#
# File ~\PycharmProjects\erisBot\.venv\Lib\site-packages\mss\factory.py:35, in mss(**kwargs)
#      32     return linux.MSS(**kwargs)
#      34 if os_ == "windows":
# ---> 35     from mss import windows  # noqa: PLC0415
#      37     return windows.MSS(**kwargs)
#      39 msg = f"System {os_!r} not (yet?) implemented."
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1022, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1118, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1218, in get_data(self, path)
#
# KeyboardInterrupt:
